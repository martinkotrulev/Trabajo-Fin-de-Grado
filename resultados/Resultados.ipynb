# %%
import numpy as np
import scipy.stats as ss
import matplotlib.pyplot as plt
import pandas as pd

# %%
DH = pd.read_excel('DH_2.xlsx') #Abrimos el archivo csv
DH.head() #Visualimos los 5 primeros elementos
# Out:
#        total  water    csf     gm     wm   eyes    fat
# pac_1  0.065  0.243  0.450  0.198  0.179  1.047  4.637
# pac_2  0.081  3.311  2.383  1.143  1.690  6.746  5.183
# pac_3  0.104  1.652  1.826  0.736  0.907  1.603  4.187
# pac_4  0.045  1.431  1.465  0.555  0.816  1.346  3.926
# pac_5  0.168  1.695  1.278  0.729  0.739  1.825  4.294

# %%
DH.describe()
# Out:
#           total     water       csf        gm        wm      eyes       fat
# count  9.000000  9.000000  9.000000  9.000000  9.000000  9.000000  9.000000
# mean   0.083222  1.959667  1.563333  0.750444  0.797778  2.037556  4.671889
# std    0.036297  0.977132  0.610422  0.308686  0.406412  1.810104  0.521134
# min    0.045000  0.243000  0.450000  0.198000  0.179000  1.047000  3.926000
# 25%    0.065000  1.431000  1.278000  0.555000  0.690000  1.212000  4.294000
# 50%    0.067000  1.695000  1.527000  0.736000  0.816000  1.346000  4.637000
# 75%    0.092000  2.827000  1.885000  1.023000  0.858000  1.825000  5.129000
# max    0.168000  3.311000  2.383000  1.143000  1.690000  6.746000  5.401000

# %%
DH.boxplot(grid=False, rot= 60, fontsize= 10, figsize = (7,7))

# %%
DICE = pd.read_excel('DICE_2.xlsx') #Abrimos el archivo csv
DICE.head() #Visualimos los 5 primeros elementos
# Out:
#        total  water   csf    gm    wm  eyes   fat
# pac_1   0.93   0.82  0.65  0.84  0.86  0.07  0.23
# pac_2   0.91   0.07  0.13  0.42  0.26  0.00  0.01
# pac_3   0.93   0.22  0.14  0.52  0.50  0.20  0.06
# pac_4   0.94   0.27  0.23  0.61  0.49  0.34  0.04
# pac_5   0.90   0.18  0.30  0.54  0.56  0.24  0.07

# %%
DICE.describe()
# Out:
#           total     water       csf        gm        wm      eyes       fat
# count  9.000000  9.000000  9.000000  9.000000  9.000000  9.000000  9.000000
# mean   0.924444  0.247778  0.264444  0.545556  0.545556  0.215556  0.065556
# std    0.013333  0.229389  0.161795  0.133052  0.158596  0.130395  0.065405
# min    0.900000  0.070000  0.130000  0.410000  0.260000  0.000000  0.010000
# 25%    0.920000  0.120000  0.140000  0.440000  0.500000  0.120000  0.030000
# 50%    0.930000  0.180000  0.230000  0.520000  0.530000  0.240000  0.040000
# 75%    0.930000  0.270000  0.300000  0.610000  0.560000  0.340000  0.070000
# max    0.940000  0.820000  0.650000  0.840000  0.860000  0.360000  0.230000

# %%
DICE.boxplot(grid=False, rot= 60, fontsize= 10, figsize = (8,8))

# %%
VOL_SIM = pd.read_excel('VOL_SIM_2.xlsx') #Abrimos el archivo csv
VOL_SIM.head() #Visualimos los 5 primeros elementos
# Out:
#        total  water    csf     gm     wm   eyes    fat
# pac_1  0.994  0.890  0.862  0.985  0.976  0.073  0.689
# pac_2  0.934  0.555  0.916  0.972  0.418  0.067  0.025
# pac_3  0.970  0.572  0.623  0.887  0.891  0.380  0.393
# pac_4  0.976  0.509  0.871  0.953  0.683  0.724  0.162
# pac_5  0.946  0.671  0.810  0.961  0.839  0.772  0.631

# %%
VOL_SIM.describe()
# Out:
#           total     water       csf        gm        wm      eyes       fat
# count  9.000000  9.000000  9.000000  9.000000  9.000000  9.000000  9.000000
# mean   0.969000  0.748778  0.884333  0.927000  0.842333  0.493000  0.357222
# std    0.018815  0.177896  0.115405  0.045288  0.187043  0.286163  0.220397
# min    0.934000  0.509000  0.623000  0.868000  0.418000  0.067000  0.025000
# 25%    0.964000  0.572000  0.862000  0.887000  0.839000  0.347000  0.162000
# 50%    0.974000  0.773000  0.916000  0.942000  0.891000  0.608000  0.359000
# 75%    0.977000  0.890000  0.956000  0.961000  0.976000  0.724000  0.473000
# max    0.994000  0.978000  0.997000  0.985000  0.998000  0.775000  0.689000

# %%
VOL_SIM.boxplot(grid=False, rot= 60, fontsize= 10, figsize = (7,7))
